# %% [markdown]
# # Evaluate localization strategies
#
# This notebook does a comparative evaluation of different localization strategies.
# - Defines a base interface for localization
# - Implements a few localization strategies
# - Defines an evaluator that runs a test suite on those localization strategies
# - Evaluator dumps the results in a pandas dataframe
# - Uses Milvus as the vector database
# - Uses OpenAI's embeddings model
# - Uses langchain's abstractions for processing

# %%
import os
import tempfile
import pandas as pd
import shutil
from typing import Dict, List, Tuple
from abc import ABC, abstractmethod

from se_agent.localizer import localize_issue
from se_agent.project import Project
from se_agent.project_manager import ProjectManager

# %% [markdown]
# ## Base interface for localization strategies

# %%
class Strategy(ABC):
    @abstractmethod
    def localize(self, issue: Dict[str, str], top_n: int) -> List[Tuple[str, str]]:
        """
        Localizes the issue to a set of relevant packages and files.

        Args:
            issue (Dict[str, str]): A dictionary containing issue details with at least:
                - `title` (str): The title of the issue.
                - `description` (str): The detailed description of the issue.
            top_n (int): The maximum number of localization results to return.

        Returns:
            List[Tuple[str, str]]: A list of tuples representing relevant localization results,
                each containing `package` (str) and `file` (str).
        """
        pass

# %% [markdown]
# ## Hierarchical localization strategy
#
# Instead of semantic vector search, this strategy uses the completion API to generate localization results. This requires inlining the context. Using all the files in the repository as context, far-exceed the permitted token limits of the completion API. Therefore, it uses generated semantic summaries of the code files as context. However, for large repositories, and depending on the model used, this may still exceed the token limits. Therefore, it also generates higher-level summaries at the level of packages. Let us assume that the aggregated package summaries are within the token limits. The strategy operates as follows:
#
# - **Package level**: Given an issue, it first identifies the package that are relevant to the issue query belongs to, using packages summaries in the inline context.
# - **File level**: It then identifies the files within the package that are relevant to the issue query, using file summaries for the relevant packages in the inline context.
#
# This strategy is more expensive than the semantic vector search strategy.

# %%
class HierarchicalLocalizationStrategy(Strategy):
    def __init__(self, project: Project, strategy_name: str = "Hierarchical Completion"):
        self.project = project
        self.strategy_name = strategy_name

    def localize(self, issue: Dict[str, str], top_n: int) -> List[Tuple[str, str]]:
        """
        Localizes an issue to specific files by first identifying relevant packages
        and then narrowing down to specific files in those packages.
        """
        # issue conversation
        issue_conversation = {
            "title": issue["title"],
            "conversation": [{'role': 'user', 'content': f'Issue: {issue["title"]}\n\nDescription: {issue["description"]}'}]
        }

        # Localize the issue using the hierarchical approach
        localization_suggestions = localize_issue(self.project, issue, issue_conversation)

        if localization_suggestions is None:
            return []  # If localization fails, return an empty list

        # Format the results as (package, file) tuples, sorted by confidence
        return [(suggestion.package, os.path.splitext(suggestion.file)[0]) for suggestion in localization_suggestions[:top_n]]

# %% [markdown]
# ## Dataset

# %%
from typing import List, Dict, Iterator
import yaml
import os

class Issue:
    def __init__(self, id: str, title: str, content: str, expected_results: List[str]):
        self.id = id
        self.title = title
        self.content = content
        self.expected_results = expected_results

    def to_dict(self) -> Dict[str, str]:
        """Returns the issue data as a dictionary for easy access."""
        return {"title": self.title, "description": self.content}

class Dataset:
    def __init__(self, yaml_path: str):
        self.yaml_dir = os.path.dirname(yaml_path)  # Get the directory containing the YAML file
        with open(yaml_path, 'r') as f:
            data = yaml.safe_load(f)
        self.test_cases = data["test_cases"]

    def __iter__(self) -> Iterator[Issue]:
        """Allows iteration over Issue instances created from test cases."""
        for case in self.test_cases:
            # Construct the full path to the markdown file
            full_path = os.path.join(self.yaml_dir, case["filepath"])
            # Load the content from the markdown file
            with open(full_path, 'r') as f:
                content = f.read()
            # Create an Issue instance for each test case
            yield Issue(
                id=case["id"],
                title=case["title"],
                content=content,
                expected_results=case["expected_results"]
            )

dataset = Dataset("test/dataset.yaml")

# %% [markdown]
# ## Evaluator

# %%
class LocalizationEvaluator:
    def __init__(self, dataset: Dataset, strategies_to_evaluate: List[Strategy]):
        self.dataset = dataset
        self.strategies = strategies_to_evaluate

    def calculate_score(self, expected_results: List[str], actual_results: List[str]) -> float:
        """Calculates the score with distance-based penalties for expected results outside the top-k."""
        score = 1.0  # Start with a perfect score of 1

        for expected in expected_results:
            if expected in actual_results:
                index = actual_results.index(expected)
                # Check if expected item is within the top-k
                if index >= len(expected_results):
                    # Distance-based partial penalty if it's outside top-k but present in results
                    distance_factor = index - len(expected_results) + 1
                    penalty = (1 / len(expected_results)) * distance_factor * 0.2
                    score -= penalty
            else:
                # Full penalty if expected item is missing altogether
                score -= 1 / len(expected_results)

        return max(score, 0)  # Ensure score doesn't go below 0

    def evaluate(self) -> pd.DataFrame:
        """Evaluates each strategy on all test issues and returns a DataFrame with results and scores."""
        df = pd.DataFrame(columns=["Issue Title", "Expected Results"] + [f"Results ({strategy.strategy_name})" for strategy in self.strategies])

        # Dictionary to store total scores per strategy
        total_scores = {strategy.strategy_name: 0 for strategy in self.strategies}

        # Iterate over each Issue in the dataset
        for issue in self.dataset:
            issue_data = {"title": issue.title, "description": issue.content}  # Prepare data for localization
            row_data = {
                "Issue Title": issue.title,
                "Expected Results": issue.expected_results
            }

            # Calculate and store results and formatted score+results for each strategy
            for strategy in self.strategies:
                actual_results = [res[1] for res in strategy.localize(issue_data, top_n=5)]
                score = self.calculate_score(issue.expected_results, actual_results)
                total_scores[strategy.strategy_name] += score  # Accumulate score for total

                # Format results with score as requested
                formatted_result = f"{score:.2f} {actual_results}"
                row_data[f"Results ({strategy.strategy_name})"] = formatted_result

            # Append row data to DataFrame
            df = pd.concat([df, pd.DataFrame([row_data])], ignore_index=True)

        # Append total scores row to DataFrame
        total_row = {"Issue Title": "Total", "Expected Results": ""}
        for strategy in self.strategies:
            total_row[f"Results ({strategy.strategy_name})"] = f"{total_scores[strategy.strategy_name]:.2f}"

        df = pd.concat([df, pd.DataFrame([total_row])], ignore_index=True)
        return df

# %% [markdown]
# **Test setup**

# %%
projects_store = "/Users/pdhoolia/projects-store"
repo_full_name = "pdhoolia/se-agent"
src_dir = "se_agent"

project_manager = ProjectManager(projects_store)
project_info = project_manager.get_project(repo_full_name)
project = Project(os.getenv("GITHUB_TOKEN"), projects_store, project_info)

# %% [markdown]
# **Strategies**

# %%
hierarchical_strategy = HierarchicalLocalizationStrategy(project, strategy_name="Hierarchical Localization")
strategies_to_evaluate = [hierarchical_strategy]

# %% [markdown]
# **Evaluate**

# %%
evaluator = LocalizationEvaluator(
    dataset=dataset,
    strategies_to_evaluate=strategies_to_evaluate
)

evaluation_results = evaluator.evaluate()
# Out:
# 2024-11-11 18:57:48,101 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'lambda']
# 2024-11-11 18:58:03,981 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='se_agent.project_info', file='project_info.py', confidence=0.9, reason='The ProjectInfo class needs to be updated to include the github_token as an optional parameter.'), FileLocalizationSuggestion(package='se_agent.project', file='project.py', confidence=0.8, reason='The Project class uses the github_token for authentication and needs to be updated to use the project-level token if present.'), FileLocalizationSuggestion(package='se_agent.project_manager', file='project_manager.py', confidence=0.7, reason='The ProjectManager class may need to be updated to handle the new optional github_token parameter when adding or retrieving projects.'), FileLocalizationSuggestion(package='se_agent.onboard_agent', file='onboard_agent.py', confidence=0.6, reason='The onboard_agent function may need to be updated to pass the github_token to the ProjectManager when onboarding a new project.')]
# 2024-11-11 18:58:11,749 - se-agent - DEBUG - Relevant Packages: ['llm']
# 2024-11-11 18:58:27,092 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='llm', file='api.py', confidence=0.8, reason='The `call_llm_for_task` function in this file is responsible for calling the language model, and it may be the point where RateLimitError is handled or propagated.'), FileLocalizationSuggestion(package='llm', file='retry_with_backoff.py', confidence=0.9, reason='This file defines a decorator function that implements a retry mechanism with exponential backoff, which could be used to handle RateLimitError in LLM calls.')]
# 2024-11-11 19:00:51,472 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'llm', 'util']
# 2024-11-11 19:01:09,431 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='listener_core', file='listener_core.py', confidence=0.9, reason='The listener_core module is responsible for processing GitHub events, including issue comments.'), FileLocalizationSuggestion(package='issue_analyzer', file='issue_analyzer.py', confidence=0.85, reason='The issue_analyzer module needs to be updated to handle issue comments and create a conversation thread.'), FileLocalizationSuggestion(package='localizer', file='localizer.py', confidence=0.8, reason='The localizer module needs to be updated to handle the new conversation thread format and generate change suggestions based on the conversation.'), FileLocalizationSuggestion(package='llm', file='api.py', confidence=0.75, reason='The llm module needs to be updated to handle the new prompt format and generate responses based on the conversation thread.'), FileLocalizationSuggestion(package='project', file='project.py', confidence=0.7, reason='The project module may need to be updated to handle the new conversation thread format and store the conversation history.')]
# 2024-11-11 19:03:37,854 - se-agent - DEBUG - Relevant Packages: ['repository_analyzer', 'se_agent', 'llm']
# 2024-11-11 19:11:04,582 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='repository_analyzer', file='file_analyzer.py', confidence=0.9, reason='File analyzer generates package details and file-level semantic summaries, crucial for updating semantic understanding.'), FileLocalizationSuggestion(package='repository_analyzer', file='package_summary.py', confidence=0.85, reason='Package summary generator creates high-level semantic summaries for each package, necessary for localization and updating.'), FileLocalizationSuggestion(package='se_agent', file='listener_core.py', confidence=0.8, reason='Listener core processes webhook events, including code push events to the main branch, triggering the update of semantic understanding.'), FileLocalizationSuggestion(package='se_agent', file='project.py', confidence=0.75, reason='Project interfaces with the GitHub API and manages local metadata, including updating the semantic understanding of the codebase.')]
# 2024-11-11 19:11:16,997 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'lambda', 'util']
# 2024-11-11 19:15:36,081 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='flask_server', file='flask_server.py', confidence=0.9, reason='Contains the Flask app and route definitions, including the new /onboard route.'), FileLocalizationSuggestion(package='project_manager', file='project_manager.py', confidence=0.8, reason='Manages project data and provides methods to add, retrieve, and list projects, which is relevant to the onboarding process.'), FileLocalizationSuggestion(package='project_info', file='project_info.py', confidence=0.7, reason='Defines the ProjectInfo data class, which is used to represent project information and is relevant to the onboarding process.'), FileLocalizationSuggestion(package='onboard_agent', file='onboard_agent.py', confidence=0.6, reason='Contains the onboard_agent function, which is responsible for onboarding a project and may need to be modified to support the new API-based onboarding process.'), FileLocalizationSuggestion(package='lambda', file='lambda_function.py', confidence=0.5, reason='Defines the Lambda function that listens for onboarding and GitHub webhook events, and may need to be modified to support the new API-based onboarding process.')]
# 2024-11-11 19:15:46,488 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'lambda']
# 2024-11-11 19:16:00,395 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='se_agent.lambda', file='lambda_function.py', confidence=0.95, reason='The lambda function is being moved into the se_agent package, and this file is the main entry point for the lambda function.'), FileLocalizationSuggestion(package='se_agent', file='__init__.py', confidence=0.8, reason='The __init__.py file may need to be updated to include the new lambda sub-package.'), FileLocalizationSuggestion(package='se_agent', file='Dockerfile', confidence=0.85, reason='The Dockerfile needs to be updated to reflect the new location of the lambda_function.py file.')]
# 2024-11-11 19:16:22,652 - se-agent - DEBUG - Relevant Packages: ['repository_analyzer', 'llm', 'se_agent']
# 2024-11-11 19:16:44,486 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='repository_analyzer', file='file_analyzer.py', confidence=0.8, reason='Contains functions for generating semantic descriptions of code files.'), FileLocalizationSuggestion(package='repository_analyzer', file='package_summary.py', confidence=0.75, reason='Defines functions for generating summaries of Python packages.'), FileLocalizationSuggestion(package='project', file='project.py', confidence=0.9, reason='Contains the `update_codebase_understanding` function that calls semantic summary generation.'), FileLocalizationSuggestion(package='se_agent', file='localizer.py', confidence=0.7, reason='Provides a structured output parsing approach that can be used as a reference.')]
# 2024-11-11 19:22:55,190 - se-agent - DEBUG - Relevant Packages: ['repository_analyzer', 'util']
# 2024-11-11 19:23:20,121 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='repository_analyzer', file='package_summary.py', confidence=0.9, reason='The issue is related to package summary generation, and this file contains the relevant functions.'), FileLocalizationSuggestion(package='util', file='file_count.py', confidence=0.7, reason='This file contains a function to recursively count files in a folder, which could be modified to extract code structure names.'), FileLocalizationSuggestion(package='util', file='folder_count.py', confidence=0.6, reason='This file contains a function to recursively count folders in a directory, which could be used to navigate package structure.'), FileLocalizationSuggestion(package='repository_analyzer', file='file_analyzer.py', confidence=0.5, reason='This file contains functions to generate semantic descriptions of code files, which could be used to generate package summary.')]
# 2024-11-11 19:23:24,281 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'llm', 'repository_analyzer']
# 2024-11-11 19:23:39,456 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='repository_analyzer', file='file_analyzer.py', confidence=0.8, reason='The file_analyzer.py file is responsible for generating semantic descriptions of code files, which is relevant to the issue of retrieval-based localization.'), FileLocalizationSuggestion(package='repository_analyzer', file='package_summary.py', confidence=0.75, reason='The package_summary.py file generates summaries of Python packages, which is related to the issue of localizing files relevant to an issue.'), FileLocalizationSuggestion(package='llm', file='api.py', confidence=0.7, reason='The api.py file in the llm package is responsible for interfacing with language models, which is necessary for implementing the retrieval-based localization strategy.'), FileLocalizationSuggestion(package='llm', file='model_configuration_manager.py', confidence=0.65, reason='The model_configuration_manager.py file manages the configuration of language models, which is relevant to the issue of adding embedding as a task to the model configurations.'), FileLocalizationSuggestion(package='project', file='project.py', confidence=0.6, reason='The project.py file is responsible for managing project metadata, which is related to the issue of creating a vector index during project onboarding.')]
# 2024-11-11 19:26:42,700 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'lambda', 'util']
# 2024-11-11 19:29:11,056 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='project', file='project.py', confidence=0.9, reason='The project.py file contains functions for loading and saving checkpoints, which is relevant to the issue of implementing checkpointing during onboarding and updating semantic understanding.'), FileLocalizationSuggestion(package='project', file='project_manager.py', confidence=0.8, reason='The project_manager.py file manages project data and provides methods to add, retrieve, and list projects, which may be related to maintaining processed information and optimizing resumed requests.'), FileLocalizationSuggestion(package='project', file='project_info.py', confidence=0.7, reason='The project_info.py file encapsulates project information, including repository details and optional configurations, which could be relevant to maintaining processed information and optimizing resumed requests.')]
# 2024-11-11 19:29:20,210 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'util']
# 2024-11-11 19:29:35,272 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='project', file='project.py', confidence=0.8, reason='The project.py file contains the Project class which is responsible for managing GitHub repositories and updating codebase understanding.'), FileLocalizationSuggestion(package='project', file='project_info.py', confidence=0.7, reason='The project_info.py file defines the ProjectInfo data class which holds project-related information such as repository name and source folder.'), FileLocalizationSuggestion(package='project', file='project_manager.py', confidence=0.6, reason='The project_manager.py file contains the ProjectManager class which manages a collection of projects and provides methods to add, retrieve, and list projects.')]
# 2024-11-11 19:29:42,558 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'llm']
# 2024-11-11 19:32:26,025 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='se_agent', file='project_info.py', confidence=0.9, reason='ProjectInfo class can be modified to include top-n packages and files configurations'), FileLocalizationSuggestion(package='se_agent', file='localizer.py', confidence=0.85, reason='Localizer component uses top-n packages and files configurations'), FileLocalizationSuggestion(package='se_agent', file='change_suggester.py', confidence=0.8, reason='Change suggester component uses top-n packages and files configurations'), FileLocalizationSuggestion(package='se_agent', file='project_manager.py', confidence=0.75, reason='ProjectManager class can be used to store and retrieve project-level configurations')]
# 2024-11-11 19:36:01,750 - se-agent - DEBUG - Relevant Packages: ['repository_analyzer', 'util']
# 2024-11-11 19:44:55,542 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='repository_analyzer', file='file_analyzer.py', confidence=0.9, reason='Contains a function to check for empty files before generating semantic descriptions.'), FileLocalizationSuggestion(package='repository_analyzer', file='package_summary.py', confidence=0.6, reason='May need to be updated to exclude empty files when generating package summaries.')]
# 2024-11-11 19:45:43,268 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'util']
# 2024-11-11 19:45:50,739 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='se_agent', file='project.py', confidence=0.95, reason='Error stacktrace points to this file, specifically the save_checkpoint method.'), FileLocalizationSuggestion(package='se_agent', file='__init__.py', confidence=0.6, reason='Logger configuration might be related to error logging.')]
# 2024-11-11 19:52:54,034 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'lambda', 'util']
# 2024-11-11 19:54:12,797 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='se_agent', file='project.py', confidence=0.9, reason='The error occurs in the clone_repository method of the Project class, which is defined in this file.'), FileLocalizationSuggestion(package='se_agent', file='listener_core.py', confidence=0.8, reason='The onboard_project function in this file calls the onboard method of the Project class, which leads to the error.'), FileLocalizationSuggestion(package='se_agent', file='onboard_agent.py', confidence=0.6, reason='This file contains the onboard_agent function, which may be related to the onboarding process that triggers the error.')]
# 2024-11-11 19:54:19,104 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'lambda']
# 2024-11-11 20:00:49,022 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='listener_core', file='listener_core.py', confidence=0.9, reason="The function `process_issue_event` in this file is responsible for handling issue events, including comments. It's likely that the logic for ignoring comments on closed issues should be implemented here."), FileLocalizationSuggestion(package='issue_analyzer', file='issue_analyzer.py', confidence=0.7, reason="This file contains the function `analyze_issue` which is used to analyze issue comments. It's possible that the issue state is checked here, and if so, the logic for ignoring comments on closed issues could be added."), FileLocalizationSuggestion(package='project', file='project.py', confidence=0.5, reason="The `Project` class in this file has a method `fetch_issue_comments` which fetches comments on a specified GitHub issue. It's possible that the issue state is checked here, and if so, the logic for ignoring comments on closed issues could be added.")]
# 2024-11-11 20:02:46,586 - se-agent - DEBUG - Relevant Packages: ['lambda', 'se_agent', 'repository_analyzer']
# 2024-11-11 20:03:40,447 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='lambda', file='lambda_function.py', confidence=0.8, reason='The lambda function is responsible for processing incoming events, including the onboard event, which is a long-running process.'), FileLocalizationSuggestion(package='se_agent', file='flask_server.py', confidence=0.8, reason='The Flask server handles the onboard route, which is a potentially long-running event that requires cloning the repository and generating semantic understanding for each code file.'), FileLocalizationSuggestion(package='se_agent', file='onboard_agent.py', confidence=0.7, reason='The onboard agent is responsible for onboarding the agent onto the requested GitHub repository, which involves cloning the repository and generating semantic understanding for each code file.'), FileLocalizationSuggestion(package='se_agent', file='project.py', confidence=0.6, reason='The project class manages GitHub repositories, including cloning and updating the codebase understanding, which is a long-running process.'), FileLocalizationSuggestion(package='se_agent', file='project_manager.py', confidence=0.5, reason='The project manager class manages a collection of projects, including loading, saving, and adding projects, which may be affected by the long-running onboard process.')]
# 2024-11-11 20:03:49,608 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'lambda']
# Error calling LLM for localization: The read operation timed out
# 2024-11-11 20:14:12,583 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'llm']
# 2024-11-11 20:17:41,886 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='se_agent', file='listener_core.py', confidence=0.9, reason='Core processing logic for issue analysis and decision making for response'), FileLocalizationSuggestion(package='llm', file='api.py', confidence=0.85, reason="Implementation of new LLM task 'response_decision' for decision classification"), FileLocalizationSuggestion(package='se_agent', file='project.py', confidence=0.8, reason='Enhancements to add emoji reactions to comments using GitHub API'), FileLocalizationSuggestion(package='se_agent', file='issue_analyzer.py', confidence=0.75, reason='Issue analysis and conversation compilation for decision making'), FileLocalizationSuggestion(package='llm', file='model_configuration_manager.py', confidence=0.7, reason="Configuration management for new LLM task 'response_decision'")]
# 2024-11-11 20:17:55,718 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'llm', 'util']
# 2024-11-11 20:18:08,007 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='se_agent', file='issue_analyzer.py', confidence=0.8, reason='Analyzing issue comments for domain understanding corrections'), FileLocalizationSuggestion(package='se_agent', file='localizer.py', confidence=0.75, reason='Generating condensed memories of domain understanding corrections'), FileLocalizationSuggestion(package='llm', file='api.py', confidence=0.7, reason='Defining a new LLM task for generating memories'), FileLocalizationSuggestion(package='project', file='project.py', confidence=0.65, reason='Storing memories in a JSON file in the metadata folder'), FileLocalizationSuggestion(package='listener_core', file='listener_core.py', confidence=0.6, reason='Retrieving memories when processing new issues or comments')]
# 2024-11-11 20:22:41,606 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'llm']
# 2024-11-11 20:23:03,194 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='flask_server', file='flask_server.py', confidence=0.8, reason='The Flask server is responsible for handling API endpoints, and the memories API endpoint will be added to this file.'), FileLocalizationSuggestion(package='project', file='project.py', confidence=0.7, reason='The project class manages project-related data and functionality, and may need to be updated to handle memories.'), FileLocalizationSuggestion(package='project_manager', file='project_manager.py', confidence=0.6, reason='The project manager class handles project data storage and retrieval, and may need to be updated to handle memories.')]
# 2024-11-11 20:23:23,305 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'repository_analyzer', 'util']
# 2024-11-11 20:23:38,232 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='project', file='project.py', confidence=0.9, reason='The project class manages GitHub repositories and updates codebase understanding, which is relevant to storing package details documents.'), FileLocalizationSuggestion(package='project', file='project_manager.py', confidence=0.8, reason='The ProjectManager class manages project data stored in a JSON file, which could be extended to store package details documents.'), FileLocalizationSuggestion(package='repository_analyzer', file='package_summary.py', confidence=0.7, reason='The package_summary module generates package level summaries and could be modified to store the package details document in the cache.')]
# 2024-11-11 20:23:48,846 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'repository_analyzer', 'util']
# 2024-11-11 20:27:51,583 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='project', file='project.py', confidence=0.9, reason='The project class manages GitHub repositories and updates codebase understanding, which is relevant to storing package details documents.'), FileLocalizationSuggestion(package='project', file='project_manager.py', confidence=0.8, reason='The ProjectManager class manages project data stored in a JSON file, which could be extended to store package details documents.'), FileLocalizationSuggestion(package='repository_analyzer', file='package_summary.py', confidence=0.7, reason='The package_summary module generates package level summaries and could be modified to store the package details document in the cache.')]

# %% [markdown]
# **Display results**

# %%
# Create a copy of the DataFrame for display purposes
display_df = evaluation_results.copy()

# Set the index to start from 1
display_df.index = display_df.index + 1

# Apply left alignment to all columns, including headers
df_style = display_df.style \
    .set_table_attributes("style='width:100%'") \
    .set_properties(**{'text-align': 'left'}) \
    .set_table_styles([{
        'selector': 'th',
        'props': [('text-align', 'left')]
    }])

df_style
# Out:
# <style type="text/css">
# #T_6a944 th {
#   text-align: left;
# }
# #T_6a944_row0_col0, #T_6a944_row0_col1, #T_6a944_row0_col2, #T_6a944_row1_col0, #T_6a944_row1_col1, #T_6a944_row1_col2, #T_6a944_row2_col0, #T_6a944_row2_col1, #T_6a944_row2_col2, #T_6a944_row3_col0, #T_6a944_row3_col1, #T_6a944_row3_col2, #T_6a944_row4_col0, #T_6a944_row4_col1, #T_6a944_row4_col2, #T_6a944_row5_col0, #T_6a944_row5_col1, #T_6a944_row5_col2, #T_6a944_row6_col0, #T_6a944_row6_col1, #T_6a944_row6_col2, #T_6a944_row7_col0, #T_6a944_row7_col1, #T_6a944_row7_col2, #T_6a944_row8_col0, #T_6a944_row8_col1, #T_6a944_row8_col2, #T_6a944_row9_col0, #T_6a944_row9_col1, #T_6a944_row9_col2, #T_6a944_row10_col0, #T_6a944_row10_col1, #T_6a944_row10_col2, #T_6a944_row11_col0, #T_6a944_row11_col1, #T_6a944_row11_col2, #T_6a944_row12_col0, #T_6a944_row12_col1, #T_6a944_row12_col2, #T_6a944_row13_col0, #T_6a944_row13_col1, #T_6a944_row13_col2, #T_6a944_row14_col0, #T_6a944_row14_col1, #T_6a944_row14_col2, #T_6a944_row15_col0, #T_6a944_row15_col1, #T_6a944_row15_col2, #T_6a944_row16_col0, #T_6a944_row16_col1, #T_6a944_row16_col2, #T_6a944_row17_col0, #T_6a944_row17_col1, #T_6a944_row17_col2, #T_6a944_row18_col0, #T_6a944_row18_col1, #T_6a944_row18_col2, #T_6a944_row19_col0, #T_6a944_row19_col1, #T_6a944_row19_col2, #T_6a944_row20_col0, #T_6a944_row20_col1, #T_6a944_row20_col2, #T_6a944_row21_col0, #T_6a944_row21_col1, #T_6a944_row21_col2, #T_6a944_row22_col0, #T_6a944_row22_col1, #T_6a944_row22_col2, #T_6a944_row23_col0, #T_6a944_row23_col1, #T_6a944_row23_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_6a944" style='width:100%'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a944_level0_col0" class="col_heading level0 col0" >Issue Title</th>
#       <th id="T_6a944_level0_col1" class="col_heading level0 col1" >Expected Results</th>
#       <th id="T_6a944_level0_col2" class="col_heading level0 col2" >Results (Hierarchical Localization)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a944_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_6a944_row0_col0" class="data row0 col0" >Project level override for github token</td>
#       <td id="T_6a944_row0_col1" class="data row0 col1" >['project', 'project_info', 'onboard_agent']</td>
#       <td id="T_6a944_row0_col2" class="data row0 col2" >0.93 ['project_info', 'project', 'project_manager', 'onboard_agent']</td>
#     </tr>
#     <tr>
#       <th id="T_6a944_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_6a944_row1_col0" class="data row1 col0" >Retry LLM call on Rate Limit Error</td>
#       <td id="T_6a944_row1_col1" class="data row1 col1" >['retry_with_backoff', 'api']</td>
#       <td id="T_6a944_row1_col2" class="data row1 col2" >1.00 ['api', 'retry_with_backoff']</td>
#     </tr>
#     <tr>
#       <th id="T_6a944_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_6a944_row2_col0" class="data row2 col0" >Handle issue comments as well</td>
#       <td id="T_6a944_row2_col1" class="data row2 col1" >['listener_core', 'issue_analyzer', 'localizer', 'change_suggester', 'project']</td>
#       <td id="T_6a944_row2_col2" class="data row2 col2" >0.80 ['listener_core', 'issue_analyzer', 'localizer', 'api', 'project']</td>
#     </tr>
#     <tr>
#       <th id="T_6a944_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_6a944_row3_col0" class="data row3 col0" >Update semantic understanding on code push to the main branch</td>
#       <td id="T_6a944_row3_col1" class="data row3 col1" >['listener_core', 'project', 'file_analyzer', 'package_summary']</td>
#       <td id="T_6a944_row3_col2" class="data row3 col2" >1.00 ['file_analyzer', 'package_summary', 'listener_core', 'project']</td>
#     </tr>
#     <tr>
#       <th id="T_6a944_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_6a944_row4_col0" class="data row4 col0" >API based onboarding for a new project</td>
#       <td id="T_6a944_row4_col1" class="data row4 col1" >['listener_core', 'flask_server', 'lambda_function', 'project_manager', 'project']</td>
#       <td id="T_6a944_row4_col2" class="data row4 col2" >0.60 ['flask_server', 'project_manager', 'project_info', 'onboard_agent', 'lambda_function']</td>
#     </tr>
#     <tr>
#       <th id="T_6a944_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_6a944_row5_col0" class="data row5 col0" >Move lambda function within the se_agent package structure</td>
#       <td id="T_6a944_row5_col1" class="data row5 col1" >['lambda_function']</td>
#       <td id="T_6a944_row5_col2" class="data row5 col2" >1.00 ['lambda_function', '__init__', 'Dockerfile']</td>
#     </tr>
#     <tr>
#       <th id="T_6a944_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_6a944_row6_col0" class="data row6 col0" >Use structured output for semantic summary generation</td>
#       <td id="T_6a944_row6_col1" class="data row6 col1" >['localizer', 'file_analyzer', 'package_summary', 'project']</td>
#       <td id="T_6a944_row6_col2" class="data row6 col2" >1.00 ['file_analyzer', 'package_summary', 'project', 'localizer']</td>
#     </tr>
#     <tr>
#       <th id="T_6a944_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_6a944_row7_col0" class="data row7 col0" >Tool based (no LLM) code structure name generation</td>
#       <td id="T_6a944_row7_col1" class="data row7 col1" >['package_summary', 'project']</td>
#       <td id="T_6a944_row7_col2" class="data row7 col2" >0.50 ['package_summary', 'file_count', 'folder_count', 'file_analyzer']</td>
#     </tr>
#     <tr>
#       <th id="T_6a944_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_6a944_row8_col0" class="data row8 col0" >Retrieval based localization</td>
#       <td id="T_6a944_row8_col1" class="data row8 col1" >['localizer', 'project', 'api', 'model_configuration_manager']</td>
#       <td id="T_6a944_row8_col2" class="data row8 col2" >0.70 ['file_analyzer', 'package_summary', 'api', 'model_configuration_manager', 'project']</td>
#     </tr>
#     <tr>
#       <th id="T_6a944_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_6a944_row9_col0" class="data row9 col0" >Checkpoint</td>
#       <td id="T_6a944_row9_col1" class="data row9 col1" >['project']</td>
#       <td id="T_6a944_row9_col2" class="data row9 col2" >1.00 ['project', 'project_manager', 'project_info']</td>
#     </tr>
#     <tr>
#       <th id="T_6a944_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_6a944_row10_col0" class="data row10 col0" >More tolerance for package name during file fetch</td>
#       <td id="T_6a944_row10_col1" class="data row10 col1" >['project']</td>
#       <td id="T_6a944_row10_col2" class="data row10 col2" >1.00 ['project', 'project_info', 'project_manager']</td>
#     </tr>
#     <tr>
#       <th id="T_6a944_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_6a944_row11_col0" class="data row11 col0" >Override top-n[packages|files] configs at project level</td>
#       <td id="T_6a944_row11_col1" class="data row11 col1" >['project_info', 'localizer', 'change_suggester', 'project']</td>
#       <td id="T_6a944_row11_col2" class="data row11 col2" >0.75 ['project_info', 'localizer', 'change_suggester', 'project_manager']</td>
#     </tr>
#     <tr>
#       <th id="T_6a944_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_6a944_row12_col0" class="data row12 col0" >Exclude empty files from semantic analysis</td>
#       <td id="T_6a944_row12_col1" class="data row12 col1" >['project', 'file_analyzer']</td>
#       <td id="T_6a944_row12_col2" class="data row12 col2" >0.50 ['file_analyzer', 'package_summary']</td>
#     </tr>
#     <tr>
#       <th id="T_6a944_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_6a944_row13_col0" class="data row13 col0" >Error while saving a check-point</td>
#       <td id="T_6a944_row13_col1" class="data row13 col1" >['project']</td>
#       <td id="T_6a944_row13_col2" class="data row13 col2" >1.00 ['project', '__init__']</t
