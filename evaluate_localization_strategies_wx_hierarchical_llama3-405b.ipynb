# %% [markdown]
# # Evaluate localization strategies
#
# This notebook does a comparative evaluation of different localization strategies.
# - Defines a base interface for localization
# - Implements a few localization strategies
# - Defines an evaluator that runs a test suite on those localization strategies
# - Evaluator dumps the results in a pandas dataframe
# - Uses Milvus as the vector database
# - Uses OpenAI's embeddings model
# - Uses langchain's abstractions for processing

# %%
import os
import tempfile
import pandas as pd
import shutil
import yaml

from typing import Dict, List, Tuple, Iterator
from abc import ABC, abstractmethod

from se_agent.localizer import localize_issue
from se_agent.project import Project
from se_agent.project_manager import ProjectManager

# %% [markdown]
# ## Base interface for localization strategies

# %%
class Strategy(ABC):
    @abstractmethod
    def localize(self, issue: Dict[str, str], top_n: int) -> List[Tuple[str, str]]:
        """
        Localizes the issue to a set of relevant packages and files.

        Args:
            issue (Dict[str, str]): A dictionary containing issue details with at least:
                - `title` (str): The title of the issue.
                - `description` (str): The detailed description of the issue.
            top_n (int): The maximum number of localization results to return.

        Returns:
            List[Tuple[str, str]]: A list of tuples representing relevant localization results,
                each containing `package` (str) and `file` (str).
        """
        pass

# %% [markdown]
# ## Hierarchical localization strategy
#
# Instead of semantic vector search, this strategy uses the completion API to generate localization results. This requires inlining the context. Using all the files in the repository as context, far-exceed the permitted token limits of the completion API. Therefore, it uses generated semantic summaries of the code files as context. However, for large repositories, and depending on the model used, this may still exceed the token limits. Therefore, it also generates higher-level summaries at the level of packages. Let us assume that the aggregated package summaries are within the token limits. The strategy operates as follows:
#
# - **Package level**: Given an issue, it first identifies the package that are relevant to the issue query belongs to, using packages summaries in the inline context.
# - **File level**: It then identifies the files within the package that are relevant to the issue query, using file summaries for the relevant packages in the inline context.
#
# This strategy is more expensive than the semantic vector search strategy.

# %%
class HierarchicalLocalizationStrategy(Strategy):
    def __init__(self, project: Project, strategy_name: str = "Hierarchical Completion"):
        self.project = project
        self.strategy_name = strategy_name

    def localize(self, issue: Dict[str, str], top_n: int) -> List[Tuple[str, str]]:
        """
        Localizes an issue to specific files by first identifying relevant packages
        and then narrowing down to specific files in those packages.
        """
        # issue conversation
        issue_conversation = {
            "title": issue["title"],
            "conversation": [{'role': 'user', 'content': f'Issue: {issue["title"]}\n\nDescription: {issue["description"]}'}]
        }

        # Localize the issue using the hierarchical approach
        localization_suggestions = localize_issue(self.project, issue, issue_conversation)

        if localization_suggestions is None:
            return []  # If localization fails, return an empty list

        # Format the results as (package, file) tuples, sorted by confidence
        return [(suggestion.package, os.path.splitext(suggestion.file)[0]) for suggestion in localization_suggestions[:top_n]]

# %% [markdown]
# ## Dataset

# %%
class Issue:
    def __init__(self, id: str, title: str, content: str, expected_results: List[str]):
        self.id = id
        self.title = title
        self.content = content
        self.expected_results = expected_results

    def to_dict(self) -> Dict[str, str]:
        """Returns the issue data as a dictionary for easy access."""
        return {"title": self.title, "description": self.content}

class Dataset:
    def __init__(self, yaml_path: str):
        self.yaml_dir = os.path.dirname(yaml_path)  # Get the directory containing the YAML file
        with open(yaml_path, 'r') as f:
            data = yaml.safe_load(f)
        self.test_cases = data["test_cases"]

    def __iter__(self) -> Iterator[Issue]:
        """Allows iteration over Issue instances created from test cases."""
        for case in self.test_cases:
            # Construct the full path to the markdown file
            full_path = os.path.join(self.yaml_dir, case["filepath"])
            # Load the content from the markdown file
            with open(full_path, 'r') as f:
                content = f.read()
            # Create an Issue instance for each test case
            yield Issue(
                id=case["id"],
                title=case["title"],
                content=content,
                expected_results=case["expected_results"]
            )

    def __len__(self) -> int:
        """Returns the number of test cases in the dataset."""
        return len(self.test_cases)

dataset = Dataset("test/dataset.yaml")

# %% [markdown]
# ## Evaluator

# %%
class LocalizationEvaluator:
    def __init__(self, dataset: Dataset, strategies_to_evaluate: List[Strategy]):
        self.dataset = dataset
        self.strategies = strategies_to_evaluate

    def calculate_score(self, expected_results: List[str], actual_results: List[str]) -> float:
        """Calculates the score with distance-based penalties for expected results outside the top-k."""
        score = 1.0  # Start with a perfect score of 1

        for expected in expected_results:
            if expected in actual_results:
                index = actual_results.index(expected)
                # Check if expected item is within the top-k
                if index >= len(expected_results):
                    # Distance-based partial penalty if it's outside top-k but present in results
                    distance_factor = index - len(expected_results) + 1
                    penalty = (1 / len(expected_results)) * distance_factor * 0.2
                    score -= penalty
            else:
                # Full penalty if expected item is missing altogether
                score -= 1 / len(expected_results)

        return max(score, 0)  # Ensure score doesn't go below 0

    def evaluate(self) -> pd.DataFrame:
        """Evaluates each strategy on all test issues and returns a DataFrame with results and scores."""
        df = pd.DataFrame(columns=["Issue Title", "Expected Results"] + [f"Results ({strategy.strategy_name})" for strategy in self.strategies])

        # Dictionary to store total scores per strategy
        total_scores = {strategy.strategy_name: 0 for strategy in self.strategies}

        # Iterate over each Issue in the dataset
        for issue in self.dataset:
            issue_data = {"title": issue.title, "description": issue.content}  # Prepare data for localization
            row_data = {
                "Issue Title": issue.title,
                "Expected Results": issue.expected_results
            }

            # Calculate and store results and formatted score+results for each strategy
            for strategy in self.strategies:
                actual_results = [res[1] for res in strategy.localize(issue_data, top_n=5)]
                score = self.calculate_score(issue.expected_results, actual_results)
                total_scores[strategy.strategy_name] += score  # Accumulate score for total

                # Format results with score as requested
                formatted_result = f"{score:.2f} {actual_results}"
                row_data[f"Results ({strategy.strategy_name})"] = formatted_result

            # Append row data to DataFrame
            df = pd.concat([df, pd.DataFrame([row_data])], ignore_index=True)

        # Append total scores row to DataFrame
        total_row = {"Issue Title": "Score", "Expected Results": ""}
        for strategy in self.strategies:
            total_row[f"Results ({strategy.strategy_name})"] = f"{(total_scores[strategy.strategy_name]/len(self.dataset))*100:.2f}%"

        df = pd.concat([df, pd.DataFrame([total_row])], ignore_index=True)
        return df

# %% [markdown]
# **Test setup**

# %%
os.environ["LLM_PROVIDER_NAME"] = "watsonx"

projects_store = "/Users/pdhoolia/projects-store"
repo_full_name = "pdhoolia/se-agent"
src_dir = "se_agent"

project_manager = ProjectManager(projects_store)
project_info = project_manager.get_project(repo_full_name)
project = Project(os.getenv("GITHUB_TOKEN"), projects_store, project_info)

# %% [markdown]
# **Strategies**

# %%
hierarchical_strategy = HierarchicalLocalizationStrategy(project, strategy_name="Hierarchical Localization")
strategies_to_evaluate = [hierarchical_strategy]

# %% [markdown]
# **Evaluate**

# %%
evaluator = LocalizationEvaluator(
    dataset=dataset,
    strategies_to_evaluate=strategies_to_evaluate
)

evaluation_results = evaluator.evaluate()
# Out:
# 2024-11-17 22:10:37,189 - se-agent - DEBUG - Relevant Packages: ['se_agent']
# 2024-11-17 22:10:47,016 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='project', file='project.py', confidence=0.8, reason='Project class handles GitHub repository onboarding and analysis, and stores project information including GitHub token.'), FileLocalizationSuggestion(package='project_info', file='project_info.py', confidence=0.7, reason='ProjectInfo class stores metadata about a project, including repository name, source folder, API URL, and GitHub token.'), FileLocalizationSuggestion(package='onboard_agent', file='onboard_agent.py', confidence=0.6, reason='OnboardAgent script facilitates project onboarding, including parsing command-line arguments and validating environment variables, which may include the GitHub token.')]
# 2024-11-17 22:10:53,981 - se-agent - DEBUG - Relevant Packages: ['llm']
# 2024-11-17 22:11:00,733 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='llm', file='api.py', confidence=0.8, reason='Function call_llm_for_task invokes the language model with retry logic'), FileLocalizationSuggestion(package='llm', file='retry_with_backoff.py', confidence=0.9, reason='Decorator retry_with_exponential_backoff is defined for retrying functions on exceptions')]
# 2024-11-17 22:11:09,035 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'llm']
# 2024-11-17 22:11:20,299 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='se_agent.listener_core', file='listener_core.py', confidence=0.8, reason='GitHub listener needs to be updated to listen for issue comment events and handle SE Agent comments.'), FileLocalizationSuggestion(package='se_agent.issue_analyzer', file='issue_analyzer.py', confidence=0.7, reason="Issue analysis needs to be updated to handle conversation threads and add a 'comments' field to the analysis result."), FileLocalizationSuggestion(package='se_agent.localizer', file='localizer.py', confidence=0.6, reason='Localization prompt generation needs to be updated to return a Prompt object with a list of messages instead of a single string.'), FileLocalizationSuggestion(package='llm.api', file='api.py', confidence=0.5, reason='LLM call functions need to be refactored to take the structured prompt as input.')]
# 2024-11-17 22:11:31,756 - se-agent - DEBUG - Relevant Packages: ['repository_analyzer', 'se_agent']
# 2024-11-17 22:11:42,916 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='repository_analyzer', file='file_analyzer.py', confidence=0.8, reason='File contains functionality for generating semantic descriptions of Python code files'), FileLocalizationSuggestion(package='repository_analyzer', file='package_summary.py', confidence=0.7, reason='File provides functions to generate a semantic summary of a Python package'), FileLocalizationSuggestion(package='se_agent', file='listener_core.py', confidence=0.9, reason='File implements a GitHub integration for onboarding projects and processing webhook events'), FileLocalizationSuggestion(package='se_agent', file='project.py', confidence=0.8, reason='File defines a Project class that manages the onboarding and analysis of GitHub repositories')]
# 2024-11-17 22:11:51,748 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'lambda']
# 2024-11-17 22:12:03,819 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='se_agent', file='flask_server.py', confidence=0.8, reason='This file contains the Flask web server setup and API endpoint definitions, including the onboard_project_route function that handles POST and PUT requests for onboarding new projects.'), FileLocalizationSuggestion(package='se_agent', file='onboard_agent.py', confidence=0.7, reason='This file contains the onboard_agent function that manages the onboarding process for new projects, including parsing command-line arguments and validating environment variables.'), FileLocalizationSuggestion(package='lambda', file='lambda_function.py', confidence=0.6, reason='This file contains the handler function for the AWS Lambda function that listens for onboarding and GitHub webhook events, including the onboard_project function that handles POST and PUT requests for onboarding new projects.')]
# 2024-11-17 22:12:09,442 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'lambda']
# 2024-11-17 22:12:18,642 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='lambda', file='lambda_function.py', confidence=0.8, reason='The issue discusses moving the lambda function wrapper into the core se_agent package, specifically referencing lambda_function.py.'), FileLocalizationSuggestion(package='se_agent', file='__init__.py', confidence=0.4, reason="The issue mentions creating a sub-package 'lambda' inside 'se_agent', which may involve modifying the __init__.py file."), FileLocalizationSuggestion(package='None', file='Dockerfile', confidence=0.6, reason='The issue mentions updating the Dockerfile to reflect changes in the package structure.')]
# 2024-11-17 22:12:31,072 - se-agent - DEBUG - Relevant Packages: ['repository_analyzer', 'se_agent']
# 2024-11-17 22:12:43,152 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='repository_analyzer', file='file_analyzer.py', confidence=0.8, reason='Contains functionality for generating semantic descriptions of Python code files'), FileLocalizationSuggestion(package='repository_analyzer', file='package_summary.py', confidence=0.7, reason='Provides functions to generate a semantic summary of a Python package'), FileLocalizationSuggestion(package='se_agent', file='project.py', confidence=0.9, reason='Manages the onboarding and analysis of GitHub repositories, including semantic summary generation')]
# 2024-11-17 22:12:50,502 - se-agent - DEBUG - Relevant Packages: ['repository_analyzer', 'util']
# 2024-11-17 22:12:59,418 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='repository_analyzer', file='package_summary.py', confidence=0.8, reason='Contains the current implementation of package summary generation using LLM, which needs to be modified.'), FileLocalizationSuggestion(package='util', file='file_count.py', confidence=0.6, reason='Provides functionality to recursively count files in a folder, which can be used as a reference for navigating code files in a package.'), FileLocalizationSuggestion(package='util', file='folder_count.py', confidence=0.6, reason='Provides functionality to recursively count folders in a directory, which can be used as a reference for navigating sub-packages in a package.')]
# 2024-11-17 22:13:06,285 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'llm', 'util']
# 2024-11-17 22:13:14,676 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='se_agent', file='localizer.py', confidence=0.8, reason='Current localizer implementation'), FileLocalizationSuggestion(package='llm', file='api.py', confidence=0.7, reason='LLM interfacing and embedding model configuration'), FileLocalizationSuggestion(package='se_agent', file='project.py', confidence=0.6, reason='Project onboarding and semantic summary generation')]
# 2024-11-17 22:13:21,785 - se-agent - DEBUG - Relevant Packages: ['se_agent']
# 2024-11-17 22:13:28,401 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='project', file='project.py', confidence=0.9, reason='The project.py file contains functions for loading, saving, and deleting checkpoints, which are relevant to implementing checkpointing for onboarding and updating semantic understanding.')]
# 2024-11-17 22:13:33,570 - se-agent - DEBUG - Relevant Packages: ['se_agent']
# 2024-11-17 22:13:39,455 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='project', file='project.py', confidence=0.8, reason='The project.py file contains the fetch_code_files function which is responsible for fetching code files. This function needs to be modified to be more tolerant of package names.')]
# 2024-11-17 22:13:46,273 - se-agent - DEBUG - Relevant Packages: ['se_agent']
# 2024-11-17 22:13:57,083 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='project_info', file='project_info.py', confidence=0.8, reason='ProjectInfo class contains metadata attributes related to a project, including top N packages and files configuration.'), FileLocalizationSuggestion(package='project_manager', file='project_manager.py', confidence=0.7, reason='ProjectManager class manages project data, including loading and saving project information that may contain top N packages and files configuration.'), FileLocalizationSuggestion(package='localizer', file='localizer.py', confidence=0.6, reason='Localizer component uses top N packages configuration to identify relevant packages for issue localization.'), FileLocalizationSuggestion(package='change_suggester', file='change_suggester.py', confidence=0.6, reason='Change suggester component uses top N files configuration to generate change suggestions based on issue analysis.')]
# 2024-11-17 22:14:01,393 - se-agent - DEBUG - Relevant Packages: ['repository_analyzer']
# 2024-11-17 22:14:07,623 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='repository_analyzer', file='file_analyzer.py', confidence=0.8, reason='Function generate_semantic_description checks for empty files before analysis.')]
# 2024-11-17 22:14:13,018 - se-agent - DEBUG - Relevant Packages: ['se_agent']
# 2024-11-17 22:14:17,921 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='se_agent.project', file='project.py', confidence=0.9, reason='Error occurred in the save_checkpoint method of the Project class')]
# 2024-11-17 22:14:21,950 - se-agent - DEBUG - Relevant Packages: ['se_agent']
# 2024-11-17 22:14:29,232 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='se_agent.project', file='project.py', confidence=0.8, reason='The error occurs in the clone_repository method of the Project class, which is defined in this file.'), FileLocalizationSuggestion(package='se_agent.listener_core', file='listener_core.py', confidence=0.6, reason='The onboard_project function in this file calls the onboard method of the Project class, which leads to the error.')]
# 2024-11-17 22:14:32,146 - se-agent - DEBUG - Relevant Packages: ['se_agent']
# 2024-11-17 22:14:39,727 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='se_agent.listener_core', file='listener_core.py', confidence=0.8, reason='Function process_issue_event handles issue comments and issue creation events, and is likely to be responsible for ignoring comments on closed issues.'), FileLocalizationSuggestion(package='se_agent.listener_core', file='listener_core.py', confidence=0.7, reason='Constant IGNORE_TOKEN is used to signify ignored comments or actions by the agent, and may be used to ignore comments on closed issues.')]
# 2024-11-17 22:14:48,964 - se-agent - DEBUG - Relevant Packages: ['lambda', 'se_agent']
# 2024-11-17 22:14:58,001 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='lambda', file='lambda_function.py', confidence=0.8, reason='The lambda function handles onboarding events and may require refactoring for asynchronous processing.'), FileLocalizationSuggestion(package='se_agent.flask_server', file='flask_server.py', confidence=0.8, reason='The Flask server handles onboarding events and may require refactoring for asynchronous processing.'), FileLocalizationSuggestion(package='se_agent.project', file='project.py', confidence=0.7, reason='The project class manages repository onboarding and may be affected by the refactoring.')]
# 2024-11-17 22:15:03,696 - se-agent - DEBUG - Relevant Packages: ['se_agent']
# 2024-11-17 22:15:11,374 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='listener_core', file='listener_core.py', confidence=0.8, reason='This file contains the core logic for processing webhook events, including issue comments and labeling, which is relevant to the feature of labeling issues as off-limit.'), FileLocalizationSuggestion(package='project', file='project.py', confidence=0.7, reason='This file defines the Project class that manages the onboarding and analysis of GitHub repositories, including issue management, which may need to be updated to handle off-limit issues.')]
# 2024-11-17 22:15:14,893 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'llm']
# 2024-11-17 22:15:24,476 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='listener_core', file='listener_core.py', confidence=0.8, reason='Core processing logic for issue analysis and decision making for response'), FileLocalizationSuggestion(package='llm', file='api.py', confidence=0.7, reason="Definition of LLM tasks, including the new 'response_decision' task"), FileLocalizationSuggestion(package='project', file='project.py', confidence=0.6, reason='GitHub API integration for adding emoji reactions to comments')]
# 2024-11-17 22:15:31,814 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'llm']
# 2024-11-17 22:15:42,867 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='se_agent', file='issue_analyzer.py', confidence=0.8, reason='Analyzing issue comments for domain understanding corrections'), FileLocalizationSuggestion(package='se_agent', file='localizer.py', confidence=0.75, reason='Generating localization prompts with domain memories'), FileLocalizationSuggestion(package='se_agent', file='change_suggester.py', confidence=0.7, reason='Using domain memories in change suggestion prompts'), FileLocalizationSuggestion(package='llm', file='api.py', confidence=0.85, reason='Defining a new LLM task for generating domain memories'), FileLocalizationSuggestion(package='se_agent', file='project.py', confidence=0.65, reason='Storing and retrieving domain memories in project metadata')]
# 2024-11-17 22:15:50,529 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'llm', 'lambda']
# 2024-11-17 22:15:59,026 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='se_agent', file='flask_server.py', confidence=0.8, reason='This file contains the Flask web server setup and API endpoint definitions, which is relevant to adding a new API endpoint for managing memories.'), FileLocalizationSuggestion(package='se_agent', file='project.py', confidence=0.7, reason='This file defines the Project class, which manages project data and may need to be updated to store and retrieve memories.')]
# 2024-11-17 22:16:07,619 - se-agent - DEBUG - Relevant Packages: ['repository_analyzer', 'se_agent']
# 2024-11-17 22:16:15,296 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='repository_analyzer', file='package_summary.py', confidence=0.8, reason='Package summary generation is related to the issue of caching package details documents.'), FileLocalizationSuggestion(package='se_agent', file='project.py', confidence=0.9, reason='The project class manages the onboarding and analysis of GitHub repositories, which includes generating package summaries and caching package details documents.')]
# 2024-11-17 22:16:24,333 - se-agent - DEBUG - Relevant Packages: ['repository_analyzer', 'se_agent']
# 2024-11-17 22:16:31,700 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='repository_analyzer', file='package_summary.py', confidence=0.8, reason='Package summary generation is related to the issue of caching package details documents.'), FileLocalizationSuggestion(package='se_agent', file='project.py', confidence=0.9, reason='The project class manages the onboarding and analysis of GitHub repositories, which includes generating package summaries and caching package details documents.')]
# 2024-11-17 22:16:41,779 - se-agent - DEBUG - Relevant Packages: ['repository_analyzer', 'se_agent', 'util']
# 2024-11-17 22:16:53,411 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='repository_analyzer', file='file_analyzer.py', confidence=0.8, reason='The file_analyzer.py file is responsible for generating semantic descriptions of Python code files and may need to be updated to handle other file types.'), FileLocalizationSuggestion(package='repository_analyzer', file='package_summary.py', confidence=0.7, reason='The package_summary.py file generates semantic summaries of Python packages and may need to be updated to include information from non-code files.'), FileLocalizationSuggestion(package='se_agent', file='localizer.py', confidence=0.9, reason='The localizer.py file is responsible for localizing issues and may need to be updated to consider non-code files in its analysis.'), FileLocalizationSuggestion(package='se_agent', file='change_suggester.py', confidence=0.8, reason='The change_suggester.py file generates change suggestions and may need to be updated to include changes to non-code files.')]
# 2024-11-17 22:17:03,802 - se-agent - DEBUG - Relevant Packages: ['se_agent', 'llm', 'util']
# 2024-11-17 22:17:13,604 - se-agent - DEBUG - File Localization Suggestions: [FileLocalizationSuggestion(package='se_agent', file='localizer.py', confidence=0.8, reason='The localizer.py file contains the current implementation of the hierarchical localization strategy, which is the focus of the refactor.'), FileLocalizationSuggestion(package='se_agent', file='__init__.py', confidence=0.4, reason='The __init__.py file may need to be updated to include the new abstract localization strategy interface and configuration.'), FileLocalizationSuggestion(package='se_agent', file='project.py', confidence=0.6, reason='The project.py file will need to be updated to create a Milvus vector store and add a Milvus collection for the project as part of the semantic vector search strategy.')]

# %% [markdown]
# **Display results**

# %%
# Create a copy of the DataFrame for display purposes
display_df = evaluation_results.copy()

# Set the index to start from 1
display_df.index = display_df.index + 1

# Apply left alignment to all columns, including headers
df_style = display_df.style \
    .set_table_attributes("style='width:100%'") \
    .set_properties(**{'text-align': 'left'}) \
    .set_table_styles([{
        'selector': 'th',
        'props': [('text-align', 'left')]
    }])

df_style
# Out:
# <style type="text/css">
# #T_3111e th {
#   text-align: left;
# }
# #T_3111e_row0_col0, #T_3111e_row0_col1, #T_3111e_row0_col2, #T_3111e_row1_col0, #T_3111e_row1_col1, #T_3111e_row1_col2, #T_3111e_row2_col0, #T_3111e_row2_col1, #T_3111e_row2_col2, #T_3111e_row3_col0, #T_3111e_row3_col1, #T_3111e_row3_col2, #T_3111e_row4_col0, #T_3111e_row4_col1, #T_3111e_row4_col2, #T_3111e_row5_col0, #T_3111e_row5_col1, #T_3111e_row5_col2, #T_3111e_row6_col0, #T_3111e_row6_col1, #T_3111e_row6_col2, #T_3111e_row7_col0, #T_3111e_row7_col1, #T_3111e_row7_col2, #T_3111e_row8_col0, #T_3111e_row8_col1, #T_3111e_row8_col2, #T_3111e_row9_col0, #T_3111e_row9_col1, #T_3111e_row9_col2, #T_3111e_row10_col0, #T_3111e_row10_col1, #T_3111e_row10_col2, #T_3111e_row11_col0, #T_3111e_row11_col1, #T_3111e_row11_col2, #T_3111e_row12_col0, #T_3111e_row12_col1, #T_3111e_row12_col2, #T_3111e_row13_col0, #T_3111e_row13_col1, #T_3111e_row13_col2, #T_3111e_row14_col0, #T_3111e_row14_col1, #T_3111e_row14_col2, #T_3111e_row15_col0, #T_3111e_row15_col1, #T_3111e_row15_col2, #T_3111e_row16_col0, #T_3111e_row16_col1, #T_3111e_row16_col2, #T_3111e_row17_col0, #T_3111e_row17_col1, #T_3111e_row17_col2, #T_3111e_row18_col0, #T_3111e_row18_col1, #T_3111e_row18_col2, #T_3111e_row19_col0, #T_3111e_row19_col1, #T_3111e_row19_col2, #T_3111e_row20_col0, #T_3111e_row20_col1, #T_3111e_row20_col2, #T_3111e_row21_col0, #T_3111e_row21_col1, #T_3111e_row21_col2, #T_3111e_row22_col0, #T_3111e_row22_col1, #T_3111e_row22_col2, #T_3111e_row23_col0, #T_3111e_row23_col1, #T_3111e_row23_col2, #T_3111e_row24_col0, #T_3111e_row24_col1, #T_3111e_row24_col2, #T_3111e_row25_col0, #T_3111e_row25_col1, #T_3111e_row25_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_3111e" style='width:100%'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3111e_level0_col0" class="col_heading level0 col0" >Issue Title</th>
#       <th id="T_3111e_level0_col1" class="col_heading level0 col1" >Expected Results</th>
#       <th id="T_3111e_level0_col2" class="col_heading level0 col2" >Results (Hierarchical Localization)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3111e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_3111e_row0_col0" class="data row0 col0" >Project level override for github token</td>
#       <td id="T_3111e_row0_col1" class="data row0 col1" >['project', 'project_info', 'onboard_agent']</td>
#       <td id="T_3111e_row0_col2" class="data row0 col2" >1.00 ['project', 'project_info', 'onboard_agent']</td>
#     </tr>
#     <tr>
#       <th id="T_3111e_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_3111e_row1_col0" class="data row1 col0" >Retry LLM call on Rate Limit Error</td>
#       <td id="T_3111e_row1_col1" class="data row1 col1" >['retry_with_backoff', 'api']</td>
#       <td id="T_3111e_row1_col2" class="data row1 col2" >1.00 ['api', 'retry_with_backoff']</td>
#     </tr>
#     <tr>
#       <th id="T_3111e_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_3111e_row2_col0" class="data row2 col0" >Handle issue comments as well</td>
#       <td id="T_3111e_row2_col1" class="data row2 col1" >['listener_core', 'issue_analyzer', 'localizer', 'change_suggester', 'project']</td>
#       <td id="T_3111e_row2_col2" class="data row2 col2" >0.60 ['listener_core', 'issue_analyzer', 'localizer', 'api']</td>
#     </tr>
#     <tr>
#       <th id="T_3111e_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_3111e_row3_col0" class="data row3 col0" >Update semantic understanding on code push to the main branch</td>
#       <td id="T_3111e_row3_col1" class="data row3 col1" >['listener_core', 'project', 'file_analyzer', 'package_summary']</td>
#       <td id="T_3111e_row3_col2" class="data row3 col2" >1.00 ['file_analyzer', 'package_summary', 'listener_core', 'project']</td>
#     </tr>
#     <tr>
#       <th id="T_3111e_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_3111e_row4_col0" class="data row4 col0" >API based onboarding for a new project</td>
#       <td id="T_3111e_row4_col1" class="data row4 col1" >['listener_core', 'flask_server', 'lambda_function', 'project_manager', 'project']</td>
#       <td id="T_3111e_row4_col2" class="data row4 col2" >0.40 ['flask_server', 'onboard_agent', 'lambda_function']</td>
#     </tr>
#     <tr>
#       <th id="T_3111e_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_3111e_row5_col0" class="data row5 col0" >Move lambda function within the se_agent package structure</td>
#       <td id="T_3111e_row5_col1" class="data row5 col1" >['lambda_function']</td>
#       <td id="T_3111e_row5_col2" class="data row5 col2" >1.00 ['lambda_function', '__init__', 'Dockerfile']</td>
#     </tr>
#     <tr>
#       <th id="T_3111e_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_3111e_row6_col0" class="data row6 col0" >Use structured output for semantic summary generation</td>
#       <td id="T_3111e_row6_col1" class="data row6 col1" >['localizer', 'file_analyzer', 'package_summary', 'project']</td>
#       <td id="T_3111e_row6_col2" class="data row6 col2" >0.75 ['file_analyzer', 'package_summary', 'project']</td>
#     </tr>
#     <tr>
#       <th id="T_3111e_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_3111e_row7_col0" class="data row7 col0" >Tool based (no LLM) code structure name generation</td>
#       <td id="T_3111e_row7_col1" class="data row7 col1" >['package_summary', 'project']</td>
#       <td id="T_3111e_row7_col2" class="data row7 col2" >0.50 ['package_summary', 'file_count', 'folder_count']</td>
#     </tr>
#     <tr>
#       <th id="T_3111e_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_3111e_row8_col0" class="data row8 col0" >Retrieval based localization</td>
#       <td id="T_3111e_row8_col1" class="data row8 col1" >['localizer', 'project', 'api', 'model_configuration_manager']</td>
#       <td id="T_3111e_row8_col2" class="data row8 col2" >0.75 ['localizer', 'api', 'project']</td>
#     </tr>
#     <tr>
#       <th id="T_3111e_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_3111e_row9_col0" class="data row9 col0" >Checkpoint</td>
#       <td id="T_3111e_row9_col1" class="data row9 col1" >['project']</td>
#       <td id="T_3111e_row9_col2" class="data row9 col2" >1.00 ['project']</td>
#     </tr>
#     <tr>
#       <th id="T_3111e_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_3111e_row10_col0" class="data row10 col0" >More tolerance for package name during file fetch</td>
#       <td id="T_3111e_row10_col1" class="data row10 col1" >['project']</td>
#       <td id="T_3111e_row10_col2" class="data row10 col2" >1.00 ['project']</td>
#     </tr>
#     <tr>
#       <th id="T_3111e_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_3111e_row11_col0" class="data row11 col0" >Override top-n[packages|files] configs at project level</td>
#       <td id="T_3111e_row11_col1" class="data row11 col1" >['project_info', 'localizer', 'change_suggester', 'project']</td>
#       <td id="T_3111e_row11_col2" class="data row11 col2" >0.75 ['project_info', 'project_manager', 'localizer', 'change_suggester']</td>
#     </tr>
#     <tr>
#       <th id="T_3111e_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_3111e_row12_col0" class="data row12 col0" >Exclude empty files from semantic analysis</td>
#       <td id="T_3111e_row12_col1" class="data row12 col1" >['project', 'file_analyzer']</td>
#       <td id="T_3111e_row12_col2" class="data row12 col2" >0.50 ['file_analyzer']</td>
#     </tr>
#     <tr>
#       <th id="T_3111e_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_3111e_row13_col0" class="data row13 col0" >Error while saving a check-point</td>
#       <td id="T_3111e_row13_col1" class="data row13 col1" >['project']</td>
#       <td id="T_3111e_row13_col2" class="data row13 col2" >1.00 ['project']</td>
#     </tr>
#     <tr>
#       <th id="T_3111e_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_3111e_ro
